# %% [markdown]
# # SVEDKA Case

# %%
# imports
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.formula.api as sm

# %matplotlib inline

# %%
# importing data
df = pd.read_excel('/mnt/d/Desktop/Marketing_Analytics/Case Assignment 1 Data - Vodka Data.xlsx', 
                     sheetname = 'data')
df.head()
# Out:
#   BrandName  Brand ID  Year  Absolut  Aristocrat  Barton  Belvedere  Burnett  \
# 0   Absolut        15  1995        1           0       0          0        0
# 1   Absolut        15  1996        1           0       0          0        0
# 2   Absolut        15  1997        1           0       0          0        0
# 3   Absolut        15  1998        1           0       0          0        0
# 4   Absolut        15  1999        1           0       0          0        0
#
#    Chopin  Crystal Palac    ...     LagTotalMinusSales  TierSales  \
# 0       0              0    ...                  60903       1080
# 1       0              0    ...                  60840       1255
# 2       0              0    ...                  60532       1532
# 3       0              0    ...                  60464       1730
# 4       0              0    ...                  60306       2118
#
#    OutsideTierSales  LagTierSales  LagOutsideTierSales  Firstintro  \
# ...

# %% [markdown]
# ### Problem 1

# %%
lm_1 = sm.ols(formula='LnSales ~ PriceRerUnit + Print + Outdoor + Broad + LagTotalSales', data = df).fit()
lm_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                LnSales   R-squared:                       0.761
# Model:                            OLS   Adj. R-squared:                  0.756
# Method:                 Least Squares   F-statistic:                     163.7
# Date:                Tue, 23 Jan 2018   Prob (F-statistic):           9.73e-78
# Time:                        14:03:24   Log-Likelihood:                -211.71
# No. Observations:                 263   AIC:                             435.4
# Df Residuals:                     257   BIC:                             456.9
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### Problem 2

# %%
lm_2 = sm.ols(formula='LnSales ~ LnLPrice + PriceRerUnit + LnPrint + LnOut + LnBroad', 
              data = df).fit()
lm_2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                LnSales   R-squared:                       0.526
# Model:                            OLS   Adj. R-squared:                  0.516
# Method:                 Least Squares   F-statistic:                     54.10
# Date:                Tue, 23 Jan 2018   Prob (F-statistic):           1.18e-37
# Time:                        14:07:08   Log-Likelihood:                -279.41
# No. Observations:                 250   AIC:                             570.8
# Df Residuals:                     244   BIC:                             591.9
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### Problem 3

# %%
lm_3 = sm.ols(formula='LnSales ~ LnLPrice + PriceRerUnit + LnPrint + LnOut + LnBroad + Tier1 + Tier2', 
              data = df).fit()
lm_3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                LnSales   R-squared:                       0.612
# Model:                            OLS   Adj. R-squared:                  0.601
# Method:                 Least Squares   F-statistic:                     54.55
# Date:                Tue, 23 Jan 2018   Prob (F-statistic):           2.59e-46
# Time:                        14:08:45   Log-Likelihood:                -254.29
# No. Observations:                 250   AIC:                             524.6
# Df Residuals:                     242   BIC:                             552.8
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### Problem 4

# %%
lm_4 = sm.ols(formula='LnSales ~ LnLPrice + PriceRerUnit + LnPrint + LnOut + LnBroad + Tier1 + Tier2 + \
              LagTotalMinusSales', data = df).fit()
lm_4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                LnSales   R-squared:                       0.824
# Model:                            OLS   Adj. R-squared:                  0.818
# Method:                 Least Squares   F-statistic:                     140.8
# Date:                Tue, 23 Jan 2018   Prob (F-statistic):           2.41e-86
# Time:                        14:12:40   Log-Likelihood:                -155.65
# No. Observations:                 250   AIC:                             329.3
# Df Residuals:                     241   BIC:                             361.0
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# ...

# %% [markdown]
# Problem 5

# %%
lm_5 = sm.ols(formula='LnSales ~ LnLPrice + PriceRerUnit + LnPrint + LnOut + LnBroad + Tier1 + Tier2 + \
              LagTotalMinusSales + Firstintro', data = df).fit()
lm_5.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                LnSales   R-squared:                       0.839
# Model:                            OLS   Adj. R-squared:                  0.833
# Method:                 Least Squares   F-statistic:                     138.9
# Date:                Tue, 23 Jan 2018   Prob (F-statistic):           6.53e-90
# Time:                        14:15:31   Log-Likelihood:                -144.41
# No. Observations:                 250   AIC:                             308.8
# Df Residuals:                     240   BIC:                             344.0
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### Problem 6
#
# The reason we see blah blah blah changing is because of blah blah blah

# %% [markdown]
# ### Problem 7
#
# Our recommendations for Cuvelier is to do blah blah blah
